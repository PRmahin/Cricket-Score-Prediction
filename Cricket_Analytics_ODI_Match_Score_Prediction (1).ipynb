# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/odi.csv')

# %%
df.head(10)
# Out:
#    mid       date                                 venue bat_team bowl_team  \
# 0    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 1    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 2    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 3    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 4    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 5    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 6    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 7    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 8    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
# 9    1  6/13/2006  Civil Service Cricket Club, Stormont  England   Ireland
#
#           batsman            bowler  runs  wickets  overs  runs_last_5  \
# 0  ME Trescothick       DT Johnston     0        0    0.1            0
# 1  ME Trescothick       DT Johnston     0        0    0.2            0
# 2  ME Trescothick       DT Johnston     4        0    0.3            4
# 3  ME Trescothick       DT Johnston     6        0    0.4            6
# 4  ME Trescothick       DT Johnston     6        0    0.5            6
# 5  ME Trescothick       DT Johnston     6        0    0.6            6
# 6        EC Joyce  D Langford-Smith     6        0    1.1            6
# 7        EC Joyce  D Langford-Smith     6        0    1.2            6
# 8        EC Joyce  D Langford-Smith     6        0    1.3            6
# 9        EC Joyce  D Langford-Smith     7        0    1.3            7
#
#    wickets_last_5  striker  non-striker  total
# 0               0        0            0    301
# 1               0        0            0    301
# 2               0        0            0    301
# 3               0        0            0    301
# 4               0        0            0    301
# 5               0        0            0    301
# 6               0        0            0    301
# 7               0        0            0    301
# 8               0        0            0    301
# 9               0        0            0    301

# %% [markdown]
# ## EDA – Exploratory Data Analysis

# %%
df.shape
# Out:
# (350899, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350899 entries, 0 to 350898
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   mid             350899 non-null  int64
#  1   date            350899 non-null  object
#  2   venue           350899 non-null  object
#  3   bat_team        350899 non-null  object
#  4   bowl_team       350899 non-null  object
#  5   batsman         350899 non-null  object
#  6   bowler          350899 non-null  object
#  7   runs            350899 non-null  int64
#  8   wickets         350899 non-null  int64
#  9   overs           350899 non-null  float64
#  10  runs_last_5     350899 non-null  int64
#  11  wickets_last_5  350899 non-null  int64
#  12  striker         350899 non-null  int64
#  13  non-striker     350899 non-null  int64
#  14  total           350899 non-null  int64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 40.2+ MB

# %%
df.isnull().sum()
# Out:
# mid               0
# date              0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
df.describe()
# Out:
#                  mid           runs        wickets          overs  \
# count  350899.000000  350899.000000  350899.000000  350899.000000
# mean      594.360426     114.801661       2.974970      24.052899
# std       343.605128      77.665959       2.298959      14.235439
# min         1.000000       0.000000       0.000000       0.000000
# 25%       296.000000      51.000000       1.000000      11.600000
# 50%       596.000000     105.000000       3.000000      23.600000
# 75%       893.000000     168.000000       4.000000      36.200000
# max      1188.000000     444.000000      10.000000      49.600000
#
#          runs_last_5  wickets_last_5        striker    non-striker  \
# count  350899.000000   350899.000000  350899.000000  350899.000000
# mean       23.548303        0.669814      35.180129      12.427944
# std        11.042974        0.833895      28.115264      15.019181
# min         0.000000        0.000000       0.000000       0.000000
# 25%        17.000000        0.000000      13.000000       2.000000
# 50%        23.000000        0.000000      29.000000       7.000000
# 75%        29.000000        1.000000      50.000000      18.000000
# max       101.000000        7.000000     264.000000     149.000000
#
#                total
# count  350899.000000
# mean      255.355387
# std        62.354412
# min        44.000000
# 25%       217.000000
# 50%       257.000000
# 75%       298.000000
# max       444.000000

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1692                 arr.flags.writeable = False
#    1693         else:
# -> 1694             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695             # The underlying data was copied within _interleave, so no need
#    1696             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1751             else:
#    1752                 arr = blk.get_values(dtype)
# -> 1753             result[rl.indexer] = arr
#    1754             itemmask[rl.indexer] = 1
#    1755
#
# ValueError: could not convert string to float: '6/13/2006'

# %%
df[['date','venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
       'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
       'non-striker']][:50].plot(kind = 'area', figsize = (10,10), stacked = False)
# Out:
# <Axes: >

# %% [markdown]
# # Data Cleaning

# %%
# Removing unwanted cols - reduce memory size
cols_to_remove = ['mid' ,'date','batsman', 'bowler', 'striker', 'non-striker']
df.drop(labels=cols_to_remove , axis=1 , inplace = True)

# %%
df.head()
# Out:
#                                   venue bat_team bowl_team  runs  wickets  \
# 0  Civil Service Cricket Club, Stormont  England   Ireland     0        0
# 1  Civil Service Cricket Club, Stormont  England   Ireland     0        0
# 2  Civil Service Cricket Club, Stormont  England   Ireland     4        0
# 3  Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 4  Civil Service Cricket Club, Stormont  England   Ireland     6        0
#
#    overs  runs_last_5  wickets_last_5  total
# 0    0.1            0               0    301
# 1    0.2            0               0    301
# 2    0.3            4               0    301
# 3    0.4            6               0    301
# 4    0.5            6               0    301

# %%
df['remaining_overs'] = 49.6 - df['overs']

# %%
df['weight_overs'] = (df['remaining_overs'] / 49.6)

# %%
df['remaining_wickets'] = 10 - df['wickets']

# %%
df['weight_wicket'] = (df['remaining_wickets'] / 10)

# %%
df['merge_weight'] = (df['remaining_overs']*df['weight_overs']) + (df['remaining_wickets']*df['weight_wicket'])

# %%
# import pandas as pd
# from google.colab import files

# # Assuming you have a DataFrame 'df' that you want to save
# df.to_csv('file_name.csv', index=False)

# # Download the CSV file to your local machine
# files.download('file_name.csv')

# %%
df.head(50)
# Out:
#                                    venue bat_team bowl_team  runs  wickets  \
# 0   Civil Service Cricket Club, Stormont  England   Ireland     0        0
# 1   Civil Service Cricket Club, Stormont  England   Ireland     0        0
# 2   Civil Service Cricket Club, Stormont  England   Ireland     4        0
# 3   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 4   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 5   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 6   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 7   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 8   Civil Service Cricket Club, Stormont  England   Ireland     6        0
# 9   Civil Service Cricket Club, Stormont  England   Ireland     7        0
# 10  Civil Service Cricket Club, Stormont  England   Ireland     8        0
# 11  Civil Service Cricket Club, Stormont  England   Ireland     8        0
# 12  Civil Service Cricket Club, Stormont  England   Ireland     9        0
# 13  Civil Service Cricket Club, Stormont  England   Ireland    10        0
# 14  Civil Service Cricket Club, Stormont  England   Ireland    10        0
# 15  Civil Service Cricket Club, Stormont  England   Ireland    11        0
# 16  Civil Service Cricket Club, Stormont  England   Ireland    11        0
# 17  Civil Service Cricket Club, Stormont  England   Ireland    12        0
# 18  Civil Service Cricket Club, Stormont  England   Ireland    12        0
# 19  Civil Service Cricket Club, Stormont  England   Ireland    16        0
# 20  Civil Service Cricket Club, Stormont  England   Ireland    17        0
# 21  Civil Service Cricket Club, Stormont  England   Ireland    17        0
# 22  Civil Service Cricket Club, Stormont  England   Ireland    21        0
# 23  Civil Service Cricket Club, Stormont  England   Ireland    21        0
# 24  Civil Service Cricket Club, Stormont  England   Ireland    21        0
# 25  Civil Service Cricket Club, Stormont  England   Ireland    21        0
# 26  Civil Service Cricket Club, Stormont  England   Ireland    21        0
# 27  Civil Service Cricket Club, Stormont  England   Ireland    25        0
# 28  Civil Service Cricket Club, Stormont  England   Ireland    29        0
# 29  Civil Service Cricket Club, Stormont  England   Ireland    32        0
# 30  Civil Service Cricket Club, Stormont  England   Ireland    32        0
# 31  Civil Service Cricket Club, Stormont  England   Ireland    32        0
# 32  Civil Service Cricket Club, Stormont  England   Ireland    32        0
# 33  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 34  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 35  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 36  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 37  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 38  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 39  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 40  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 41  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 42  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 43  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 44  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 45  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 46  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 47  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 48  Civil Service Cricket Club, Stormont  England   Ireland    41        1
# 49  Civil Service Cricket Club, Stormont  England   Ireland    45        1
#
#     overs  runs_last_5  wickets_last_5  total  remaining_overs  weight_overs  \
# 0     0.1            0               0    301             49.5      0.997984
# 1     0.2            0               0    301             49.4      0.995968
# 2     0.3            4               0    301             49.3      0.993952
# 3     0.4            6               0    301             49.2      0.991935
# 4     0.5            6               0    301             49.1      0.989919
# 5     0.6            6               0    301             49.0      0.987903
# 6     1.1            6               0    301             48.5      0.977823
# 7     1.2            6               0    301             48.4      0.975806
# 8     1.3            6               0    301             48.3      0.973790
# 9     1.3            7               0    301             48.3      0.973790
# 10    1.4            8               0    301             48.2      0.971774
# 11    1.5            8               0    301             48.1      0.969758
# 12    1.6            9               0    301             48.0      0.967742
# 13    2.0           10               0    301             47.6      0.959677
# 14    2.1           10               0    301             47.5      0.957661
# 15    2.2           11               0    301             47.4      0.955645
# 16    2.3           11               0    301             47.3      0.953629
# 17    2.4           12               0    301             47.2      0.951613
# 18    2.5           12               0    301             47.1      0.949597
# 19    2.6           16               0    301             47.0      0.947581
# 20    3.0           17               0    301             46.6      0.939516
# 21    3.1           17               0    301             46.5      0.937500
# 22    3.2           21               0    301             46.4      0.935484
# 23    3.3           21               0    301             46.3      0.933468
# 24    3.4           21               0    301             46.2      0.931452
# 25    3.5           21               0    301             46.1      0.929435
# 26    3.6           21               0    301             46.0      0.927419
# 27    4.1           25               0    301             45.5      0.917339
# 28    4.2           29               0    301             45.4      0.915323
# 29    4.3           32               0    301             45.3      0.913306
# 30    4.4           32               0    301             45.2      0.911290
# 31    4.5           32               0    301             45.1      0.909274
# 32    4.6           28               0    301             45.0      0.907258
# 33    5.1           27               0    301             44.5      0.897177
# 34    5.2           27               0    301             44.4      0.895161
# 35    5.3           31               0    301             44.3      0.893145
# 36    5.4           31               0    301             44.2      0.891129
# 37    5.5           31               0    301             44.1      0.889113
# 38    5.6           31               1    301             44.0      0.887097
# 39    6.1           30               1    301             43.5      0.877016
# 40    6.2           29               1    301             43.4      0.875000
# 41    6.3           29               1    301             43.3      0.872984
# 42    6.4           28               1    301             43.2      0.870968
# 43    6.5           27               1    301             43.1      0.868952
# 44    6.6           27               1    301             43.0      0.866935
# 45    7.1           26               1    301             42.5      0.856855
# 46    7.2           26               1    301             42.4      0.854839
# 47    7.3           25               1    301             42.3      0.852823
# 48    7.4           29               1    301             42.2      0.850806
# 49    7.5           29               1    301             42.1      0.848790
#
#     remaining_wickets  weight_wicket  merge_weight
# 0                  10            1.0     59.400202
# 1                  10            1.0     59.200806
# 2                  10            1.0     59.001815
# 3                  10            1.0     58.803226
# 4                  10            1.0     58.605040
# 5                  10            1.0     58.407258
# 6                  10            1.0     57.424395
# 7                  10            1.0     57.229032
# 8                  10            1.0     57.034073
# 9                  10            1.0     57.034073
# 10                 10            1.0     56.839516
# 11                 10            1.0     56.645363
# 12                 10            1.0     56.451613
# 13                 10            1.0     55.680645
# 14                 10            1.0     55.488911
# 15                 10            1.0     55.297581
# 16                 10            1.0     55.106653
# 17                 10            1.0     54.916129
# 18                 10            1.0     54.726008
# 19                 10            1.0     54.536290
# 20                 10            1.0     53.781452
# 21                 10            1.0     53.593750
# 22                 10            1.0     53.406452
# 23                 10            1.0     53.219556
# 24                 10            1.0     53.033065
# 25                 10            1.0     52.846976
# 26                 10            1.0     52.661290
# 27                 10            1.0     51.738911
# 28                 10            1.0     51.555645
# 29                 10            1.0     51.372782
# 30                 10            1.0     51.190323
# 31                 10            1.0     51.008266
# 32                 10            1.0     50.826613
# 33                 10            1.0     49.924395
# 34                 10            1.0     49.745161
# 35                 10            1.0     49.566331
# 36                 10            1.0     49.387903
# 37                 10            1.0     49.209879
# 38                  9            0.9     47.132258
# 39                  9            0.9     46.250202
# 40                  9            0.9     46.075000
# 41                  9            0.9     45.900202
# 42                  9            0.9     45.725806
# 43                  9            0.9     45.551815
# 44                  9            0.9     45.378226
# 45                  9            0.9     44.516331
# 46                  9            0.9     44.345161
# 47                  9            0.9     44.174395
# 48                  9            0.9     44.004032
# 49                  9            0.9     43.834073

# %%
#Extract rows with venues where the game is played min 5 times
df["venue"].value_counts()[df["venue"].value_counts() > 1500].sum()
# Out:
# 305045

# %%
elig_venue = df["venue"].value_counts()[df["venue"].value_counts() > 1500].index.tolist()

# %%
df = df[df["venue"].isin(elig_venue)]
df.shape
# Out:
# (305045, 14)

# %%
data = df[["bat_team"]].value_counts()
data
# Out:
# bat_team
# Australia               40969
# Sri Lanka               38235
# Pakistan                30165
# England                 30086
# South Africa            27710
# India                   27001
# New Zealand             25479
# Bangladesh              20843
# West Indies             20226
# Zimbabwe                18063
# Afghanistan              6163
# Ireland                  5838
# Scotland                 4518
# Kenya                    2453
# Netherlands              1875
# United Arab Emirates     1421
# Canada                   1326
# Bermuda                  1164
# Asia XI                   934
# Hong Kong                 576
# dtype: int64

# %%
data2 = df[["bowl_team"]].value_counts()
data2
# Out:
# bowl_team
# India                   36685
# Pakistan                30934
# Sri Lanka               29991
# Australia               29366
# England                 29169
# West Indies             25963
# South Africa            25559
# New Zealand             23277
# Zimbabwe                21850
# Bangladesh              20716
# Ireland                  9973
# Afghanistan              5670
# Canada                   3344
# Kenya                    3015
# Scotland                 2411
# United Arab Emirates     2403
# Netherlands              1628
# Bermuda                   948
# Africa XI                 934
# Hong Kong                 905
# Papua New Guinea          304
# dtype: int64

# %%
consistent_team = ['England', 'Pakistan', 'Sri Lanka', 'Australia', 'South Africa',
       'New Zealand', 'Bangladesh', 'West Indies', 'India',
       'Afghanistan','Zimbabwe','Ireland']

# %%
cons_team = df.loc[:, ['bat_team', 'bowl_team']].value_counts()[:15]
cons_team
# Out:
# bat_team      bowl_team
# Sri Lanka     India           7548
# Australia     England         7259
# England       Australia       7044
# Australia     South Africa    6565
# Sri Lanka     Pakistan        6311
# India         Sri Lanka       6175
# Sri Lanka     Australia       5530
# Australia     West Indies     5520
#               India           5432
# Sri Lanka     England         5420
# Bangladesh    Zimbabwe        5208
# Zimbabwe      Bangladesh      4846
# Australia     New Zealand     4805
# South Africa  Pakistan        4608
# Pakistan      Sri Lanka       4583
# dtype: int64

# %%
cons_team.plot.bar()
# Out:
# <Axes: xlabel='bat_team,bowl_team'>

# %%
venue_counts = df['venue'].value_counts()

most_used_venue = venue_counts.idxmax()

print(f"The most frequently used venue is: {most_used_venue}")
# Out:
# The most frequently used venue is: Shere Bangla National Stadium

# %%
top_venues = df['venue'].value_counts()[df["venue"].value_counts() > 1500]
top_10_venues = venue_counts.head(10)

print("Top 10 venues used the most:")
print(top_10_venues)
# Out:
# Top 10 venues used the most:
# Shere Bangla National Stadium                   23577
# Harare Sports Club                              14883
# R Premadasa Stadium                             11927
# Queens Sports Club                               8980
# Sheikh Zayed Stadium                             8797
# Melbourne Cricket Ground                         7585
# Rangiri Dambulla International Stadium           7277
# Sydney Cricket Ground                            7246
# Adelaide Oval                                    7155
# Western Australia Cricket Association Ground     7003
# Name: venue, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.pie(top_10_venues, labels=top_10_venues.index, autopct='%1.1f%%', startangle=140)
plt.title('top 10 venues')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.show()

# %%
df['bat_team'].unique()
# Out:
# array(['England', 'Pakistan', 'Sri Lanka', 'Australia', 'South Africa',
#        'New Zealand', 'India', 'Zimbabwe', 'West Indies', 'Ireland',
#        'Scotland', 'Kenya', 'Bangladesh', 'Netherlands', 'Bermuda',
#        'Canada', 'Asia XI', 'Afghanistan', 'United Arab Emirates',
#        'Hong Kong'], dtype=object)

# %%
df = df[(df['bat_team'].isin(consistent_team)) & (df['bowl_team'].isin(consistent_team))]

# %%
df = df[df['overs']>=5.0]

# %%
df
# Out:
#                                                     venue   bat_team  \
# 33                   Civil Service Cricket Club, Stormont    England
# 34                   Civil Service Cricket Club, Stormont    England
# 35                   Civil Service Cricket Club, Stormont    England
# 36                   Civil Service Cricket Club, Stormont    England
# 37                   Civil Service Cricket Club, Stormont    England
# ...                                                   ...        ...
# 350894  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350895  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350896  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350897  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350898  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
#
#        bowl_team  runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 33       Ireland    33        0    5.1           27               0    301
# 34       Ireland    33        0    5.2           27               0    301
# 35       Ireland    37        0    5.3           31               0    301
# 36       Ireland    37        0    5.4           31               0    301
# 37       Ireland    37        0    5.5           31               0    301
# ...          ...   ...      ...    ...          ...             ...    ...
# 350894  Zimbabwe   201        8   49.2           39               0    203
# 350895  Zimbabwe   201        8   49.3           39               0    203
# 350896  Zimbabwe   201        8   49.4           38               0    203
# 350897  Zimbabwe   202        8   49.5           38               0    203
# 350898  Zimbabwe   203        8   49.6           38               0    203
#
#         remaining_overs  weight_overs  remaining_wickets  weight_wicket  \
# 33                 44.5      0.897177                 10            1.0
# 34                 44.4      0.895161                 10            1.0
# 35                 44.3      0.893145                 10            1.0
# 36                 44.2      0.891129                 10            1.0
# 37                 44.1      0.889113                 10            1.0
# ...                 ...           ...                ...            ...
# 350894              0.4      0.008065                  2            0.2
# 350895              0.3      0.006048                  2            0.2
# 350896              0.2      0.004032                  2            0.2
# 350897              0.1      0.002016                  2            0.2
# 350898              0.0      0.000000                  2            0.2
#
#         merge_weight
# 33         49.924395
# 34         49.745161
# 35         49.566331
# 36         49.387903
# 37         49.209879
# ...              ...
# 350894      0.403226
# 350895      0.401815
# 350896      0.400806
# 350897      0.400202
# 350898      0.400000
#
# [251626 rows x 14 columns]

# %%
df["over"] = df["overs"].apply(lambda x: str(x).split(".")[0])
df["ball_no"] = df["overs"].apply(lambda x: str(x).split(".")[1])

# %%
df.head(10)
# Out:
#                                    venue bat_team bowl_team  runs  wickets  \
# 33  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 34  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 35  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 36  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 37  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 38  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 39  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 40  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 41  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 42  Civil Service Cricket Club, Stormont  England   Ireland    37        1
#
#     overs  runs_last_5  wickets_last_5  total  remaining_overs  weight_overs  \
# 33    5.1           27               0    301             44.5      0.897177
# 34    5.2           27               0    301             44.4      0.895161
# 35    5.3           31               0    301             44.3      0.893145
# 36    5.4           31               0    301             44.2      0.891129
# 37    5.5           31               0    301             44.1      0.889113
# 38    5.6           31               1    301             44.0      0.887097
# 39    6.1           30               1    301             43.5      0.877016
# 40    6.2           29               1    301             43.4      0.875000
# 41    6.3           29               1    301             43.3      0.872984
# 42    6.4           28               1    301             43.2      0.870968
#
#     remaining_wickets  weight_wicket  merge_weight over ball_no
# 33                 10            1.0     49.924395    5       1
# 34                 10            1.0     49.745161    5       2
# 35                 10            1.0     49.566331    5       3
# 36                 10            1.0     49.387903    5       4
# 37                 10            1.0     49.209879    5       5
# 38                  9            0.9     47.132258    5       6
# 39                  9            0.9     46.250202    6       1
# 40                  9            0.9     46.075000    6       2
# 41                  9            0.9     45.900202    6       3
# 42                  9            0.9     45.725806    6       4

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df["runrate"] = (df["runs"]*6 ) / df["balls_bowled"]

# %%
df.head(50)
# Out:
#                                    venue bat_team bowl_team  runs  wickets  \
# 33  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 34  Civil Service Cricket Club, Stormont  England   Ireland    33        0
# 35  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 36  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 37  Civil Service Cricket Club, Stormont  England   Ireland    37        0
# 38  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 39  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 40  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 41  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 42  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 43  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 44  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 45  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 46  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 47  Civil Service Cricket Club, Stormont  England   Ireland    37        1
# 48  Civil Service Cricket Club, Stormont  England   Ireland    41        1
# 49  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 50  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 51  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 52  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 53  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 54  Civil Service Cricket Club, Stormont  England   Ireland    45        1
# 55  Civil Service Cricket Club, Stormont  England   Ireland    49        1
# 56  Civil Service Cricket Club, Stormont  England   Ireland    49        1
# 57  Civil Service Cricket Club, Stormont  England   Ireland    49        1
# 58  Civil Service Cricket Club, Stormont  England   Ireland    53        1
# 59  Civil Service Cricket Club, Stormont  England   Ireland    53        1
# 60  Civil Service Cricket Club, Stormont  England   Ireland    55        1
# 61  Civil Service Cricket Club, Stormont  England   Ireland    55        1
# 62  Civil Service Cricket Club, Stormont  England   Ireland    56        1
# 63  Civil Service Cricket Club, Stormont  England   Ireland    60        1
# 64  Civil Service Cricket Club, Stormont  England   Ireland    60        2
# 65  Civil Service Cricket Club, Stormont  England   Ireland    63        2
# 66  Civil Service Cricket Club, Stormont  England   Ireland    64        2
# 67  Civil Service Cricket Club, Stormont  England   Ireland    67        2
# 68  Civil Service Cricket Club, Stormont  England   Ireland    68        2
# 69  Civil Service Cricket Club, Stormont  England   Ireland    68        2
# 70  Civil Service Cricket Club, Stormont  England   Ireland    72        2
# 71  Civil Service Cricket Club, Stormont  England   Ireland    72        2
# 72  Civil Service Cricket Club, Stormont  England   Ireland    73        2
# 73  Civil Service Cricket Club, Stormont  England   Ireland    78        2
# 74  Civil Service Cricket Club, Stormont  England   Ireland    78        2
# 75  Civil Service Cricket Club, Stormont  England   Ireland    79        2
# 76  Civil Service Cricket Club, Stormont  England   Ireland    79        2
# 77  Civil Service Cricket Club, Stormont  England   Ireland    79        2
# 78  Civil Service Cricket Club, Stormont  England   Ireland    79        2
# 79  Civil Service Cricket Club, Stormont  England   Ireland    79        2
# 80  Civil Service Cricket Club, Stormont  England   Ireland    81        2
# 81  Civil Service Cricket Club, Stormont  England   Ireland    82        2
# 82  Civil Service Cricket Club, Stormont  England   Ireland    82        2
#
#     overs  runs_last_5  wickets_last_5  total  remaining_overs  weight_overs  \
# 33    5.1           27               0    301             44.5      0.897177
# 34    5.2           27               0    301             44.4      0.895161
# 35    5.3           31               0    301             44.3      0.893145
# 36    5.4           31               0    301             44.2      0.891129
# 37    5.5           31               0    301             44.1      0.889113
# 38    5.6           31               1    301             44.0      0.887097
# 39    6.1           30               1    301             43.5      0.877016
# 40    6.2           29               1    301             43.4      0.875000
# 41    6.3           29               1    301             43.3      0.872984
# 42    6.4           28               1    301             43.2      0.870968
# 43    6.5           27               1    301             43.1      0.868952
# 44    6.6           27               1    301             43.0      0.866935
# 45    7.1           26               1    301             42.5      0.856855
# 46    7.2           26               1    301             42.4      0.854839
# 47    7.3           25               1    301             42.3      0.852823
# 48    7.4           29               1    301             42.2      0.850806
# 49    7.5           29               1    301             42.1      0.848790
# 50    7.6           28               1    301             42.0      0.846774
# 51    8.1           28               1    301             41.5      0.836694
# 52    8.2           24               1    301             41.4      0.834677
# 53    8.3           24               1    301             41.3      0.832661
# 54    8.4           24               1    301             41.2      0.830645
# 55    8.5           28               1    301             41.1      0.828629
# 56    8.6           28               1    301             41.0      0.826613
# 57    9.1           24               1    301             40.5      0.816532
# 58    9.2           24               1    301             40.4      0.814516
# 59    9.3           21               1    301             40.3      0.812500
# 60    9.4           23               1    301             40.2      0.810484
# 61    9.5           23               1    301             40.1      0.808468
# 62    9.5           24               1    301             40.1      0.808468
# 63    9.6           27               1    301             40.0      0.806452
# 64   10.1           27               2    301             39.5      0.796371
# 65   10.2           26               2    301             39.4      0.794355
# 66   10.3           27               2    301             39.3      0.792339
# 67   10.4           30               2    301             39.2      0.790323
# 68   10.5           31               1    301             39.1      0.788306
# 69   10.6           31               1    301             39.0      0.786290
# 70   11.1           35               1    301             38.5      0.776210
# 71   11.2           35               1    301             38.4      0.774194
# 72   11.2           36               1    301             38.4      0.774194
# 73   11.2           41               1    301             38.4      0.774194
# 74   11.3           41               1    301             38.3      0.772177
# 75   11.4           42               1    301             38.2      0.770161
# 76   11.5           42               1    301             38.1      0.768145
# 77   11.6           42               1    301             38.0      0.766129
# 78   12.1           38               1    301             37.5      0.756048
# 79   12.2           34               1    301             37.4      0.754032
# 80   12.3           36               1    301             37.3      0.752016
# 81   12.4           37               1    301             37.2      0.750000
# 82   12.5           37               1    301             37.1      0.747984
#
#     remaining_wickets  weight_wicket  merge_weight over ball_no  balls_bowled  \
# 33                 10            1.0     49.924395    5       1            31
# 34                 10            1.0     49.745161    5       2            32
# 35                 10            1.0     49.566331    5       3            33
# 36                 10            1.0     49.387903    5       4            34
# 37                 10            1.0     49.209879    5       5            35
# 38                  9            0.9     47.132258    5       6            36
# 39                  9            0.9     46.250202    6       1            37
# 40                  9            0.9     46.075000    6       2            38
# 41                  9            0.9     45.900202    6       3            39
# 42                  9            0.9     45.725806    6       4            40
# 43                  9            0.9     45.551815    6       5            41
# 44                  9            0.9     45.378226    6       6            42
# 45                  9            0.9     44.516331    7       1            43
# 46                  9            0.9     44.345161    7       2            44
# 47                  9            0.9     44.174395    7       3            45
# 48                  9            0.9     44.004032    7       4            46
# 49                  9            0.9     43.834073    7       5            47
# 50                  9            0.9     43.664516    7       6            48
# 51                  9            0.9     42.822782    8       1            49
# 52                  9            0.9     42.655645    8       2            50
# 53                  9            0.9     42.488911    8       3            51
# 54                  9            0.9     42.322581    8       4            52
# 55                  9            0.9     42.156653    8       5            53
# 56                  9            0.9     41.991129    8       6            54
# 57                  9            0.9     41.169556    9       1            55
# 58                  9            0.9     41.006452    9       2            56
# 59                  9            0.9     40.843750    9       3            57
# 60                  9            0.9     40.681452    9       4            58
# 61                  9            0.9     40.519556    9       5            59
# 62                  9            0.9     40.519556    9       5            59
# 63                  9            0.9     40.358065    9       6            60
# 64                  8            0.8     37.856653   10       1            61
# 65                  8            0.8     37.697581   10       2            62
# 66                  8            0.8     37.538911   10       3            63
# 67                  8            0.8     37.380645   10       4            64
# 68                  8            0.8     37.222782   10       5            65
# 69                  8            0.8     37.065323   10       6            66
# 70                  8            0.8     36.284073   11       1            67
# 71                  8            0.8     36.129032   11       2            68
# 72                  8            0.8     36.129032   11       2            68
# 73                  8            0.8     36.129032   11       2            68
# 74                  8            0.8     35.974395   11       3            69
# 75                  8            0.8     35.820161   11       4            70
# 76                  8            0.8     35.666331   11       5            71
# 77                  8            0.8     35.512903   11       6            72
# 78                  8            0.8     34.751815   12       1            73
# 79                  8            0.8     34.600806   12       2            74
# 80                  8            0.8     34.450202   12       3            75
# 81                  8            0.8     34.300000   12       4            76
# 82                  8            0.8     34.150202   12       5            77
#
#      runrate
# 33  6.387097
# 34  6.187500
# 35  6.727273
# 36  6.529412
# 37  6.342857
# 38  6.166667
# 39  6.000000
# 40  5.842105
# 41  5.692308
# 42  5.550000
# 43  5.414634
# 44  5.285714
# 45  5.162791
# 46  5.045455
# 47  4.933333
# 48  5.347826
# 49  5.744681
# 50  5.625000
# 51  5.510204
# 52  5.400000
# 53  5.294118
# 54  5.192308
# 55  5.547170
# 56  5.444444
# 57  5.345455
# 58  5.678571
# 59  5.578947
# 60  5.689655
# 61  5.593220
# 62  5.694915
# 63  6.000000
# 64  5.901639
# 65  6.096774
# 66  6.095238
# 67  6.281250
# 68  6.276923
# 69  6.181818
# 70  6.447761
# 71  6.352941
# 72  6.441176
# 73  6.882353
# 74  6.782609
# 75  6.771429
# 76  6.676056
# 77  6.583333
# 78  6.493151
# 79  6.405405
# 80  6.480000
# 81  6.473684
# 82  6.389610

# %%
df.corr()
# Out:
# <ipython-input-39-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                        runs   wickets     overs  runs_last_5  wickets_last_5  \
# runs               1.000000  0.527189  0.917514     0.569542        0.190005
# wickets            0.527189  1.000000  0.710236     0.012551        0.480738
# overs              0.917514  0.710236  1.000000     0.369122        0.215732
# runs_last_5        0.569542  0.012551  0.369122     1.000000       -0.095973
# wickets_last_5     0.190005  0.480738  0.215732    -0.095973        1.000000
# total              0.351636 -0.349001  0.088394     0.475909       -0.189064
# remaining_overs   -0.917514 -0.710236 -1.000000    -0.369122       -0.215732
# weight_overs      -0.917514 -0.710236 -1.000000    -0.369122       -0.215732
# remaining_wickets -0.527189 -1.000000 -0.710236    -0.012551       -0.480738
# weight_wicket     -0.527189 -1.000000 -0.710236    -0.012551       -0.480738
# merge_weight      -0.846842 -0.762234 -0.967677    -0.252854       -0.221581
# balls_bowled       0.917555  0.710276  0.999960     0.369162        0.215763
# runrate            0.515296 -0.151404  0.196672     0.648543       -0.035656
#
#                       total  remaining_overs  weight_overs  remaining_wickets  \
# runs               0.351636        -0.917514     -0.917514          -0.527189
# wickets           -0.349001        -0.710236     -0.710236          -1.000000
# overs              0.088394        -1.000000     -1.000000          -0.710236
# runs_last_5        0.475909        -0.369122     -0.369122          -0.012551
# wickets_last_5    -0.189064        -0.215732     -0.215732          -0.480738
# total              1.000000        -0.088394     -0.088394           0.349001
# remaining_overs   -0.088394         1.000000      1.000000           0.710236
# weight_overs      -0.088394         1.000000      1.000000           0.710236
# remaining_wickets  0.349001         0.710236      0.710236           1.000000
# weight_wicket      0.349001         0.710236      0.710236           1.000000
# merge_weight       0.002140         0.967677      0.967677           0.762234
# balls_bowled       0.088401        -0.999960     -0.999960          -0.710276
# runrate            0.667842        -0.196672     -0.196672           0.151404
#
#                    weight_wicket  merge_weight  balls_bowled   runrate
# runs                   -0.527189     -0.846842      0.917555  0.515296
# wickets                -1.000000     -0.762234      0.710276 -0.151404
# overs                  -0.710236     -0.967677      0.999960  0.196672
# runs_last_5            -0.012551     -0.252854      0.369162  0.648543
# wickets_last_5         -0.480738     -0.221581      0.215763 -0.035656
# total                   0.349001      0.002140      0.088401  0.667842
# remaining_overs         0.710236      0.967677     -0.999960 -0.196672
# weight_overs            0.710236      0.967677     -0.999960 -0.196672
# remaining_wickets       1.000000      0.762234     -0.710276  0.151404
# weight_wicket           1.000000      0.762234     -0.710276  0.151404
# merge_weight            0.762234      1.000000     -0.967665 -0.112430
# balls_bowled           -0.710276     -0.967665      1.000000  0.196692
# runrate                 0.151404     -0.112430      0.196692  1.000000

# %%
final_df = df[['venue','bat_team','bowl_team','overs','runs','wickets','runrate','runs_last_5','wickets_last_5','merge_weight', 'total' ]]
final_df
# Out:
#                                                     venue   bat_team  \
# 33                   Civil Service Cricket Club, Stormont    England
# 34                   Civil Service Cricket Club, Stormont    England
# 35                   Civil Service Cricket Club, Stormont    England
# 36                   Civil Service Cricket Club, Stormont    England
# 37                   Civil Service Cricket Club, Stormont    England
# ...                                                   ...        ...
# 350894  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350895  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350896  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350897  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
# 350898  Mahinda Rajapaksa International Cricket Stadiu...  Sri Lanka
#
#        bowl_team  overs  runs  wickets   runrate  runs_last_5  wickets_last_5  \
# 33       Ireland    5.1    33        0  6.387097           27               0
# 34       Ireland    5.2    33        0  6.187500           27               0
# 35       Ireland    5.3    37        0  6.727273           31               0
# 36       Ireland    5.4    37        0  6.529412           31               0
# 37       Ireland    5.5    37        0  6.342857           31               0
# ...          ...    ...   ...      ...       ...          ...             ...
# 350894  Zimbabwe   49.2   201        8  4.074324           39               0
# 350895  Zimbabwe   49.3   201        8  4.060606           39               0
# 350896  Zimbabwe   49.4   201        8  4.046980           38               0
# 350897  Zimbabwe   49.5   202        8  4.053512           38               0
# 350898  Zimbabwe   49.6   203        8  4.060000           38               0
#
#         merge_weight  total
# 33         49.924395    301
# 34         49.745161    301
# 35         49.566331    301
# 36         49.387903    301
# 37         49.209879    301
# ...              ...    ...
# 350894      0.403226    203
# 350895      0.401815    203
# 350896      0.400806    203
# 350897      0.400202    203
# 350898      0.400000    203
#
# [251626 rows x 11 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251626 entries, 33 to 350898
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   venue           251626 non-null  object
#  1   bat_team        251626 non-null  object
#  2   bowl_team       251626 non-null  object
#  3   overs           251626 non-null  float64
#  4   runs            251626 non-null  int64
#  5   wickets         251626 non-null  int64
#  6   runrate         251626 non-null  float64
#  7   runs_last_5     251626 non-null  int64
#  8   wickets_last_5  251626 non-null  int64
#  9   merge_weight    251626 non-null  float64
#  10  total           251626 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 23.0+ MB

# %%
final_df.corr()
# Out:
# <ipython-input-42-78a045a7b3cf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_df.corr()
#                    overs      runs   wickets   runrate  runs_last_5  \
# overs           1.000000  0.917514  0.710236  0.196672     0.369122
# runs            0.917514  1.000000  0.527189  0.515296     0.569542
# wickets         0.710236  0.527189  1.000000 -0.151404     0.012551
# runrate         0.196672  0.515296 -0.151404  1.000000     0.648543
# runs_last_5     0.369122  0.569542  0.012551  0.648543     1.000000
# wickets_last_5  0.215732  0.190005  0.480738 -0.035656    -0.095973
# merge_weight   -0.967677 -0.846842 -0.762234 -0.112430    -0.252854
# total           0.088394  0.351636 -0.349001  0.667842     0.475909
#
#                 wickets_last_5  merge_weight     total
# overs                 0.215732     -0.967677  0.088394
# runs                  0.190005     -0.846842  0.351636
# wickets               0.480738     -0.762234 -0.349001
# runrate              -0.035656     -0.112430  0.667842
# runs_last_5          -0.095973     -0.252854  0.475909
# wickets_last_5        1.000000     -0.221581 -0.189064
# merge_weight         -0.221581      1.000000  0.002140
# total                -0.189064      0.002140  1.000000

# %%
import numpy as np
pd.np.random.seed(42)
final_df = final_df.sample(frac=1).reset_index(drop=True)
# Out:
# <ipython-input-43-77d7b8b66e16>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.random.seed(42)

# %%
final_df
# Out:
#                                 venue   bat_team     bowl_team  overs  runs  \
# 0                Sheikh Zayed Stadium   Pakistan   West Indies   30.5   186
# 1                     SuperSport Park  Australia  South Africa   17.3    50
# 2                      Sophia Gardens    England      Pakistan   37.3   219
# 3                              Lord's   Pakistan       England   38.6   172
# 4                         Hagley Oval  Sri Lanka   New Zealand   39.3   155
# ...                               ...        ...           ...    ...   ...
# 251621  Shere Bangla National Stadium  Australia    Bangladesh   18.6   142
# 251622          Sydney Cricket Ground    England     Australia   34.5   154
# 251623        Sharjah Cricket Stadium   Pakistan     Sri Lanka   17.1    63
# 251624                 Sophia Gardens  Sri Lanka         India   39.2   122
# 251625            R Premadasa Stadium  Australia     Sri Lanka   19.4    94
#
#         wickets   runrate  runs_last_5  wickets_last_5  merge_weight  total
# 0             1  6.032432           34               0     15.455040    308
# 1             6  2.857143           10               1     22.634073    131
# 2             4  5.840000           30               0      6.650202    302
# 3             5  4.410256           27               1      4.939516    265
# 4             5  3.924051           25               1      4.638911    218
# ...         ...       ...          ...             ...           ...    ...
# 251621        3  7.473684           15               2     24.275000    361
# 251622        6  4.421053           20               0      6.196976    214
# 251623        3  3.669903           19               2     26.195363    200
# 251624        4  3.101695            7               1      5.780645    181
# 251625        2  4.779661           22               0     24.787903    211
#
# [251626 rows x 11 columns]

# %%
import seaborn as sb
import matplotlib.pyplot as mp
dataplot = sb.heatmap(final_df.corr(), cmap="YlGnBu", annot=True)

mp.show()
# Out:
# <ipython-input-45-3d66f6d05a73>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sb.heatmap(final_df.corr(), cmap="YlGnBu", annot=True)

# %%
import matplotlib.pyplot as plt

plt.ylabel('total')
plt.title(f'Scatter Plot of others vs. total')
final_df.corr()['total'][:-1].sort_values().plot(kind='bar')
# Out:
# <ipython-input-46-90c5663d24d0>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_df.corr()['total'][:-1].sort_values().plot(kind='bar')
# <Axes: title={'center': 'Scatter Plot of others vs. total'}, ylabel='total'>

# %%
final_df["venue"].value_counts()[final_df["venue"].value_counts() > 7500].sum()
# Out:
# 52556

# %%
elig_venue1 = final_df["venue"].value_counts()[final_df["venue"].value_counts() > 9000].index.tolist()
cat_df = final_df[final_df["venue"].isin(elig_venue1)]
cat_df.shape
# Out:
# (44539, 11)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['bat_team','bowl_team','venue'])
]
,remainder='passthrough')

# %%
Y1 = final_df.total
X1 = final_df.drop('total', axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X1,Y1, test_size=0.2, random_state=100)

# %% [markdown]
# # XGBRegressor

# %%
from sklearn import metrics
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    # ('step3',XGBRegressor(n_estimators=200, objective= "reg:squarederror", learning_rate=0.05,max_depth=10, alpha=1, colsample_bytree=0.5, subsample=0.5))-> 88 percent
    # ('step3',XGBRegressor(n_estimators=200, objective= "reg:squarederror", learning_rate=0.1,max_depth=10, alpha=0.1, colsample_bytree=0.5, subsample=0.5)) -> 93 percent
    # ('step3',XGBRegressor(n_estimators=500, objective= "reg:squarederror", learning_rate=0.1,max_depth=9, alpha=2, colsample_bytree=0.3, subsample=0.8)) -> 94 percent
    # ('step3',XGBRegressor(n_estimators=700, objective= "reg:squarederror", learning_rate=0.1,max_depth=10, alpha=2, colsample_bytree=0.3, subsample=0.5)) -> mse diff:50>
    ('step3',XGBRegressor(n_estimators=700, objective= "reg:squarederror", learning_rate=0.1,max_depth=10, alpha=2, colsample_bytree=0.5, subsample=0.8))
])

# fit the model with the training data
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['bat_team', 'bowl_team',
#                                                    'venue'])])),
#                 ('step2', StandardScaler()),
#                 ('step3',
#                  XGBRegressor(alpha=2, base_score=None, booster=None,
#                               callbacks=None, colsample_bylevel=None,
#                               colsample_bynode=None, colsample_bytree=0.5,
#                               device=None, early...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.1,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=10, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=700, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
# Make predictions on the training data
y_train_pred = pipe.predict(X_train)
mae_train = metrics.mean_absolute_error(y_train, y_train_pred)
mse_train = metrics.mean_squared_error(y_train, y_train_pred)
rmse_train = metrics.mean_squared_error(y_train, y_train_pred, squared=False)
r2_train = metrics.r2_score(y_train, y_train_pred)

# Make predictions on the testing data
y_test_pred = pipe.predict(X_test)

mae_test = metrics.mean_absolute_error(y_test, y_test_pred)
mse_test = metrics.mean_squared_error(y_test, y_test_pred)
rmse_test = metrics.mean_squared_error(y_test, y_test_pred, squared=False)
r2_test = metrics.r2_score(y_test, y_test_pred)


# Print the metrics
print("Training Metrics:")
print(f"MAE: {mae_train}")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R-squared (R²): {r2_train}")

print("\nTesting Metrics:")
print(f"MAE: {mae_test}")
print(f"MSE: {mse_test}")
print(f"RMSE: {rmse_test}")
print(f"R-squared (R²): {r2_test}")
# Out:
# Training Metrics:
# MAE: 2.798155142399901
# MSE: 19.757723856046105
# RMSE: 4.444966125410418
# R-squared (R²): 0.9944501205184292
#
# Testing Metrics:
# MAE: 4.0094416112421865
# MSE: 47.38261741161974
# RMSE: 6.883503280424855
# R-squared (R²): 0.986566524290556

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train
test_r2 = r2_test

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared')
plt.ylim(0, 1)  # Set the y-axis limit to [0, 1] for R-squared values
plt.show()

# %%
import pickle
with open('pipe_xgb.pkl', 'wb') as file:
    pickle.dump(pipe, file)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import numpy as np
from sklearn import metrics

reg = LinearRegression()

pipe_reg = Pipeline(steps=[
    ('step1',trf),
    ('step3',reg)
])

pipe_reg.fit(X_train , y_train)

# Make predictions on the training data
y_train_pred1 = pipe_reg.predict(X_train)

mae_train = metrics.mean_absolute_error(y_train, y_train_pred1)
mse_train = metrics.mean_squared_error(y_train, y_train_pred1)
rmse_train = metrics.mean_squared_error(y_train, y_train_pred1, squared=False)
r2_train1 = metrics.r2_score(y_train, y_train_pred1)

# Make predictions on the test data
y_test_pred1 = pipe_reg.predict(X_test)

mae_test = metrics.mean_absolute_error(y_test, y_test_pred1)
mse_test = metrics.mean_squared_error(y_test, y_test_pred1)
rmse_test = metrics.mean_squared_error(y_test, y_test_pred1, squared=False)
r2_test1 = metrics.r2_score(y_test, y_test_pred1)


# Print the metrics
print("Training Metrics:")
print(f"MAE: {mae_train}")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R-squared (R²): {r2_train1}")
print("\nTesting Metrics:")
print(f"MAE: {mae_test}")
print(f"MSE: {mse_test}")
print(f"RMSE: {rmse_test}")
print(f"R-squared (R²): {r2_test1}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Training Metrics:
# MAE: 26.767135831771007
# MSE: 1278.2333028979583
# RMSE: 35.752388771912265
# R-squared (R²): 0.6409484800931122
#
# Testing Metrics:
# MAE: 27.00917804279897
# MSE: 1301.588627242021
# RMSE: 36.077536324450165
# R-squared (R²): 0.6309857883989253

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train1
test_r2 = r2_test1

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared')
plt.ylim(0, 1)  # Set the y-axis limit to [0, 1] for R-squared values
plt.show()

# %% [markdown]
# # ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn import metrics
import numpy as np
from sklearn import metrics

elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.9)

pipe_reg2 = Pipeline(steps=[
    ('step1',trf),
    ('step3',elastic_net)
])

pipe_reg2.fit(X_train , y_train)

# Make predictions on the training data
y_train_pred2 = pipe_reg2.predict(X_train)

mae_train = metrics.mean_absolute_error(y_train, y_train_pred2)
mse_train = metrics.mean_squared_error(y_train, y_train_pred2)
rmse_train = metrics.mean_squared_error(y_train, y_train_pred2, squared=False)
r2_train2 = metrics.r2_score(y_train, y_train_pred2)

# Make predictions on the test data
y_test_pred2 = pipe_reg2.predict(X_test)

mae_test = metrics.mean_absolute_error(y_test, y_test_pred2)
mse_test = metrics.mean_squared_error(y_test, y_test_pred2)
rmse_test = metrics.mean_squared_error(y_test, y_test_pred2, squared=False)
r2_test2 = metrics.r2_score(y_test, y_test_pred2)


# Print the metrics
print("Training Metrics:")
print(f"MAE: {mae_train}")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R-squared (R²): {r2_train2}")
print("\nTesting Metrics:")
print(f"MAE: {mae_test}")
print(f"MSE: {mse_test}")
print(f"RMSE: {rmse_test}")
print(f"R-squared (R²): {r2_test2}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Training Metrics:
# MAE: 28.293387736430688
# MSE: 1465.178952845786
# RMSE: 38.27765605213812
# R-squared (R²): 0.5884360634618371
#
# Testing Metrics:
# MAE: 28.44087972352433
# MSE: 1485.0190541405366
# RMSE: 38.53594496234051
# R-squared (R²): 0.5789813125231399

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train2
test_r2 = r2_test2

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared')
plt.ylim(0, 1)  # Set the y-axis limit to [0, 1] for R-squared values
plt.show()

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import numpy as np
from sklearn import metrics

rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

pipe_reg3 = Pipeline(steps=[
    ('step1',trf),
    ('step3',rf_regressor)
])

pipe_reg3.fit(X_train , y_train)

# Make predictions on the training data
y_train_pred3 = pipe_reg3.predict(X_train)

mae_train = metrics.mean_absolute_error(y_train, y_train_pred3)
mse_train = metrics.mean_squared_error(y_train, y_train_pred3)
rmse_train = metrics.mean_squared_error(y_train, y_train_pred3, squared=False)
r2_train3 = metrics.r2_score(y_train, y_train_pred3)

# Make predictions on the test data
y_test_pred3 = pipe_reg3.predict(X_test)

mae_test = metrics.mean_absolute_error(y_test, y_test_pred3)
mse_test = metrics.mean_squared_error(y_test, y_test_pred3)
rmse_test = metrics.mean_squared_error(y_test, y_test_pred3, squared=False)
r2_test3 = metrics.r2_score(y_test, y_test_pred3)


# Print the metrics
print("Training Metrics:")
print(f"MAE: {mae_train}")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R-squared (R²): {r2_train3}")
print("\nTesting Metrics:")
print(f"MAE: {mae_test}")
print(f"MSE: {mse_test}")
print(f"RMSE: {rmse_test}")
print(f"R-squared (R²): {r2_test3}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Training Metrics:
# MAE: 0.7270159962623893
# MSE: 4.8551063249625015
# RMSE: 2.2034305809265926
# R-squared (R²): 0.9986362166426621
#
# Testing Metrics:
# MAE: 1.9482554797482317
# MSE: 35.51672246833951
# RMSE: 5.959590797054736
# R-squared (R²): 0.9899306316404441

# %%
import pickle
with open('pipe_randomforest.pkl', 'wb') as file:
    pickle.dump(pipe_reg3, file)

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train3
test_r2 = r2_test3

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared')
plt.ylim(0, 1)  # Set the y-axis limit to [0, 1] for R-squared values
plt.show()

# %% [markdown]
# # MLPRegressor

# %%
from sklearn.neural_network import MLPRegressor

# Define the neural network regressor
nn_regressor = MLPRegressor(
    hidden_layer_sizes=(100, 50),
    activation='relu',
    solver='adam',
    random_state=42,
    max_iter=1000,
    learning_rate_init=0.001
)
# Define the steps in the pipeline
pipeline_nn = Pipeline(steps=[
    ('step1', trf),
    ('step2', StandardScaler()),
    ('step3', nn_regressor)
])

# Fit the pipeline to the training data
pipeline_nn.fit(X_train, y_train)

# Make predictions on the training data
y_train_pred_nn = pipeline_nn.predict(X_train)

mae_train_nn = metrics.mean_absolute_error(y_train, y_train_pred_nn)
mse_train_nn = metrics.mean_squared_error(y_train, y_train_pred_nn)
rmse_train_nn = metrics.mean_squared_error(y_train, y_train_pred_nn, squared=False)
r2_train_nn = metrics.r2_score(y_train, y_train_pred_nn)

# Make predictions on the test data
y_test_pred_nn = pipeline_nn.predict(X_test)

mae_test_nn = metrics.mean_absolute_error(y_test, y_test_pred_nn)
mse_test_nn = metrics.mean_squared_error(y_test, y_test_pred_nn)
rmse_test_nn = metrics.mean_squared_error(y_test, y_test_pred_nn, squared=False)
r2_test_nn = metrics.r2_score(y_test, y_test_pred_nn)

# Print the metrics for the neural network
print("Neural Network Training Metrics:")
print(f"MAE: {mae_train_nn}")
print(f"MSE: {mse_train_nn}")
print(f"RMSE: {rmse_train_nn}")
print(f"R-squared (R²): {r2_train_nn}")

print("\nNeural Network Testing Metrics:")
print(f"MAE: {mae_test_nn}")
print(f"MSE: {mse_test_nn}")
print(f"RMSE: {rmse_test_nn}")
print(f"R-squared (R²): {r2_test_nn}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Neural Network Training Metrics:
# MAE: 3.9177024975907817
# MSE: 46.9108299023125
# RMSE: 6.849148115080626
# R-squared (R²): 0.986822902565336
#
# Neural Network Testing Metrics:
# MAE: 4.125517559095339
# MSE: 53.26679620382874
# RMSE: 7.298410525849361
# R-squared (R²): 0.9848982970546376

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train_nn
test_r2 = r2_test_nn

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared for MLPRegressor')
plt.ylim(0, 1)
plt.show()

# %%
import pickle
with open('pipeline_nn.pkl', 'wb') as file:
    pickle.dump(pipeline_nn, file)

# %% [markdown]
# # Polynomial regression

# %%
cat_df

# %%
cat_df = pd.get_dummies(data = cat_df, columns = ['bat_team' , 'bowl_team', 'venue'])
cat_df.head(5)
Y = cat_df.total
X = cat_df.drop('total', axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=100)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn import metrics

# Create a Polynomial Regression model with a degree of 3
polyreg3 = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())

# Train the Polynomial Regression model on the training data
polyreg3.fit(X_train, y_train)

# Make predictions on the training data
y_train_pred4 = polyreg3.predict(X_train)

mae_train = metrics.mean_absolute_error(y_train, y_train_pred4)
mse_train = metrics.mean_squared_error(y_train, y_train_pred4)
rmse_train = metrics.mean_squared_error(y_train, y_train_pred4, squared=False)
r2_train4 = metrics.r2_score(y_train, y_train_pred4)

# Make predictions on the test data
y_test_pred4 = polyreg3.predict(X_test)

mae_test = metrics.mean_absolute_error(y_test, y_test_pred4)
mse_test = metrics.mean_squared_error(y_test, y_test_pred4)
rmse_test = metrics.mean_squared_error(y_test, y_test_pred4, squared=False)
r2_test4 = metrics.r2_score(y_test, y_test_pred4)


# Print the metrics
print("Training Metrics:")
print(f"MAE: {mae_train}")
print(f"MSE: {mse_train}")
print(f"RMSE: {rmse_train}")
print(f"R-squared (R²): {r2_train4}")
print("\nTesting Metrics:")
print(f"MAE: {mae_test}")
print(f"MSE: {mse_test}")
print(f"RMSE: {rmse_test}")
print(f"R-squared (R²): {r2_test4}")
# Out:
# Training Metrics:
# MAE: 8.843208242402422
# MSE: 181.70041527942624
# RMSE: 13.47962964177526
# R-squared (R²): 0.944646853593002
#
# Testing Metrics:
# MAE: 9.214789343343686
# MSE: 194.86189762604
# RMSE: 13.959294309743598
# R-squared (R²): 0.9387777450924099

# %%
import matplotlib.pyplot as plt

# R-squared values for training and testing
train_r2 = r2_train4
test_r2 = r2_test4

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Training', 'Testing'], [train_r2, test_r2], color=['blue', 'green'])
plt.xlabel('Dataset')
plt.ylabel('R-squared (R²)')
plt.title('Training vs. Testing R-squared')
plt.ylim(0, 1)  # Set the y-axis limit to [0, 1] for R-squared values
plt.show()

# %% [markdown]
# # Model Comparison

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the algorithm names
algorithms = ['Linear', 'Polynomial', 'ElasticNet', 'XGB', 'RandomForest','MLP']

# Define the metrics and their corresponding colors
metrics = ['MAE', 'MSE', 'R-squared']
colors = ['green', 'red', 'blue']

# Define the values for each metric and algorithm
lin_metrics_array = [27.009178, 1301.588627,  0.630985]
pol_metrics_array= [9.214789, 194.861897, 0.938777]
el_metrics_array = [28.440879, 1485.019054, 0.578981]
xgb_metrics_array = [4.174673, 50.989195, 0.985544]
rand_metrics_array = [ 1.948255, 35.516722, 0.989930]
mlp_metrics_array = [4.125517,53.266796, 0.984898]
values = {
    'Linear': lin_metrics_array,
    'Polynomial': pol_metrics_array,
    'ElasticNet': el_metrics_array,
    'XGB': xgb_metrics_array,
    'RandomForest': rand_metrics_array,
    'MLP' : mlp_metrics_array
}

# Create subplots for each metric
fig, axs = plt.subplots(len(metrics), figsize=(7, 7))

for i, metric in enumerate(metrics):
    ax = axs[i]
    metric_values = [values[alg][i] for alg in algorithms]

    # Create a bar chart for the metric with the corresponding color
    ax.bar(algorithms, metric_values, color=colors[i])
    ax.set_ylabel(metric)
    ax.set_title(f'{metric} Comparison')

# Adjust layout for subplots
plt.tight_layout()

# Show the plot
plt.show()
